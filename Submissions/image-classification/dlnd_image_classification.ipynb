# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 5
sample_id = 185
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 5:
# Samples: 10000
# Label Counts: {0: 1014, 1: 1014, 2: 952, 3: 1016, 4: 997, 5: 1025, 6: 980, 7: 977, 8: 1003, 9: 1022}
# First 20 Labels: [1, 8, 5, 1, 5, 7, 4, 3, 8, 2, 7, 2, 0, 1, 5, 9, 6, 2, 0, 8]
#
# Example of Image 185:
# Image - Min Value: 0 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
 # finding a maximum and a minimum of the pixel intensity in the whole dataset
max_value = -np.inf
min_value = np.inf
for batch_id in range(1, 6):
    features, _ = helper.load_cfar10_batch(cifar10_dataset_folder_path, batch_id)
    batch_max_value = features.max()
    batch_min_value = features.min()
    if batch_max_value > max_value:
        max_value = batch_max_value
    if batch_min_value < min_value:
        min_value = batch_min_value

def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """            
    return((x - min_value) / (max_value - min_value))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn.preprocessing import LabelBinarizer

# knowing from the data exploration step that the first batch contains all labels, we fit a LabelBinarizer on it
_, labels = helper.load_cfar10_batch(cifar10_dataset_folder_path, 1)
label_binarizer = LabelBinarizer()
label_binarizer.fit(labels)

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return(label_binarizer.transform(x))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return(tf.placeholder(tf.float32, shape = [None, image_shape[0], image_shape[1], image_shape[2]],
                                     name = 'x'))


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return(tf.placeholder(tf.float32, shape = [None, n_classes], name = 'y'))


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return(tf.placeholder(tf.float32, name="keep_prob"))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
#     # Create the weight and bias
    num_input_filters = x_tensor.get_shape().as_list()[3]
    
    weights = tf.Variable(tf.truncated_normal(shape=[conv_ksize[0], conv_ksize[1], num_input_filters, conv_num_outputs], 
                                              stddev = 1/np.sqrt(num_input_filters)))
    bias = tf.Variable(tf.zeros(shape=conv_num_outputs))
    
    # Apply a convolution to x_tensor
    model = tf.nn.conv2d(x_tensor, 
                         filter=weights, 
                         strides=[1, conv_strides[0], conv_strides[1], 1], 
                         padding='SAME')
        
    # Add bias
    model = tf.add(model, bias)
    
    # Experimenting with batch normalizaiton: after realizing how many difficulties were given by weights initialization
    model = tf.contrib.layers.batch_norm(model)
    
    # Add a nonlinear activation to the convolution
    model = tf.nn.relu(model)
    
    # Apply Max Pooling
    model = tf.nn.max_pool(model, 
                           ksize=[1, pool_ksize[0], pool_ksize[1], 1], 
                           strides=[1, pool_strides[0], pool_strides[1], 1], 
                           padding='SAME')
    
    return(model) 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    
    image_dim_1, image_dim_2, image_dim_3 = x_tensor.get_shape().as_list()[1:]
    return(tf.reshape(x_tensor, [-1, image_dim_1 * image_dim_2 * image_dim_3]))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # init weights and bias
    num_inputs = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.truncated_normal(shape = [num_inputs, num_outputs], stddev=1/np.sqrt(num_inputs)))
    bias = tf.Variable(tf.zeros(shape = num_outputs))
    # create a fully connected layer
    model = tf.matmul(x_tensor, weights)
    model = tf.add(model, bias)    
    # Experimenting with batch normalizaiton
    model = tf.contrib.layers.batch_norm(model)
    model = tf.nn.relu(model)
    return(model)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    num_inputs = x_tensor.get_shape().as_list()[1]
    # init weights and bias
    weights = tf.Variable(tf.truncated_normal(shape = [num_inputs, num_outputs], mean=0, stddev=0.1))
    bias = tf.Variable(tf.zeros(shape = num_outputs))
    # an output layer
    model = tf.matmul(x_tensor, weights)
    model = tf.add(model, bias)
    return(model)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    model = conv2d_maxpool(x, conv_num_outputs=20, conv_ksize=[2,2], conv_strides=[1,1], 
                           pool_ksize=[3,3], pool_strides=[2,2])
    model = tf.nn.dropout(model, keep_prob=keep_prob)
    model = conv2d_maxpool(model, conv_num_outputs=40, conv_ksize=[2,2], conv_strides=[1,1], 
                           pool_ksize=[3,3], pool_strides=[1,1])
    model = tf.nn.dropout(model, keep_prob=keep_prob)
    model = conv2d_maxpool(model, conv_num_outputs=70, conv_ksize=[2,2], conv_strides=[1,1], 
                           pool_ksize=[2,2], pool_strides=[1,1])
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    model = flatten(model)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    model = fully_conn(model, 700)
    model = tf.nn.dropout(model, keep_prob=keep_prob)
    model = fully_conn(model, 400)
    model = tf.nn.dropout(model, keep_prob=keep_prob)
    model = fully_conn(model, 150)
    model = tf.nn.dropout(model, keep_prob=keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    model = output(model, 10)
    
    
    # TODO: return output
    return(model)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict = {x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
#     loss, accuracy = session.run([cost, accuracy], feed_dict = {x: feature_batch, y: label_batch, keep_prob: 1.0})
#     print('Loss: {0: .3f}, accuracy: {1: .3f} %'.format(loss, 100 * accuracy))
    loss = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0})
    validation_accuracy = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.})
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss, validation_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 1024
keep_probability = 0.9

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     1.4920 Validation Accuracy: 0.459600
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.2856 Validation Accuracy: 0.510000
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.1186 Validation Accuracy: 0.541600
# Epoch  4, CIFAR-10 Batch 1:  Loss:     0.9929 Validation Accuracy: 0.565400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     0.8609 Validation Accuracy: 0.584000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     0.7209 Validation Accuracy: 0.594600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     0.5937 Validation Accuracy: 0.603800
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.4829 Validation Accuracy: 0.610000
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.3900 Validation Accuracy: 0.617000
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.3135 Validation Accuracy: 0.617400
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.2410 Validation Accuracy: 0.614600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.1932 Validation Accuracy: 0.625200
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.1535 Validation Accuracy: 0.622600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.1269 Validation Accuracy: 0.626600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.1149 Validation Accuracy: 0.625600
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.1094 Validation Accuracy: 0.614000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.0830 Validation Accuracy: 0.627800
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.0692 Validation Accuracy: 0.629400
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.0524 Validation Accuracy: 0.630000
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.0475 Validation Accuracy: 0.630200
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.0325 Validation Accuracy: 0.629000
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.0351 Validation Accuracy: 0.627800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.0356 Validation Accuracy: 0.627600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0276 Validation Accuracy: 0.628000
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0251 Validation Accuracy: 0.628400
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.0258 Validation Accuracy: 0.633000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0158 Validation Accuracy: 0.625600
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0144 Validation Accuracy: 0.635200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0113 Validation Accuracy: 0.641800
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0100 Validation Accuracy: 0.641200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0160 Validation Accuracy: 0.633600
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0067 Validation Accuracy: 0.639000
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0064 Validation Accuracy: 0.641600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0076 Validation Accuracy: 0.641600
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0051 Validation Accuracy: 0.645600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0095 Validation Accuracy: 0.643200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0042 Validation Accuracy: 0.640000
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0032 Validation Accuracy: 0.649600
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0029 Validation Accuracy: 0.640800
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0032 Validation Accuracy: 0.641800
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0033 Validation Accuracy: 0.649800
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0044 Validation Accuracy: 0.646000
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0022 Validation Accuracy: 0.642800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0028 Validation Accuracy: 0.643800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0020 Validation Accuracy: 0.642400
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0024 Validation Accuracy: 0.643200
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0025 Validation Accuracy: 0.641800
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0022 Validation Accuracy: 0.640200
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0016 Validation Accuracy: 0.649400
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0019 Validation Accuracy: 0.639000
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0027 Validation Accuracy: 0.639200
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0018 Validation Accuracy: 0.639800
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0027 Validation Accuracy: 0.641000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0016 Validation Accuracy: 0.641200
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0019 Validation Accuracy: 0.643600
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.647400
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.651600
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0015 Validation Accuracy: 0.647400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0025 Validation Accuracy: 0.646600
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.650400
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.648000
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0018 Validation Accuracy: 0.650000
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy: 0.645200
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.645600
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0031 Validation Accuracy: 0.652400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.647600
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0012 Validation Accuracy: 0.644800
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy: 0.651000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.647600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.644000
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.649800
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.642600
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.646200
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.649200
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.642000
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy: 0.644000
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.650600
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.649800
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy: 0.647800
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.646400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0077 Validation Accuracy: 0.640200
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0012 Validation Accuracy: 0.644600
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.640600
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0019 Validation Accuracy: 0.642600
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0012 Validation Accuracy: 0.647800
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.647800
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.646000
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.644000
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.648800
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.650400
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy: 0.651000
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy: 0.645800
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.643600
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.650400
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.649400
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.650400
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.646800
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.639800
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.643000
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.644200

# %%
epochs = 65

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     1.6004 Validation Accuracy: 0.433800
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.4174 Validation Accuracy: 0.480000
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.2798 Validation Accuracy: 0.521400
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.2008 Validation Accuracy: 0.539000
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.1260 Validation Accuracy: 0.565800
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.1238 Validation Accuracy: 0.583000
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.0477 Validation Accuracy: 0.588200
# Epoch  2, CIFAR-10 Batch 3:  Loss:     0.9784 Validation Accuracy: 0.600400
# Epoch  2, CIFAR-10 Batch 4:  Loss:     0.9652 Validation Accuracy: 0.615200
# Epoch  2, CIFAR-10 Batch 5:  Loss:     0.8756 Validation Accuracy: 0.628800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     0.9342 Validation Accuracy: 0.624200
# Epoch  3, CIFAR-10 Batch 2:  Loss:     0.8673 Validation Accuracy: 0.639800
# Epoch  3, CIFAR-10 Batch 3:  Loss:     0.8283 Validation Accuracy: 0.648400
# Epoch  3, CIFAR-10 Batch 4:  Loss:     0.8137 Validation Accuracy: 0.646400
# Epoch  3, CIFAR-10 Batch 5:  Loss:     0.7263 Validation Accuracy: 0.664600
# Epoch  4, CIFAR-10 Batch 1:  Loss:     0.7857 Validation Accuracy: 0.663800
# Epoch  4, CIFAR-10 Batch 2:  Loss:     0.7467 Validation Accuracy: 0.670200
# Epoch  4, CIFAR-10 Batch 3:  Loss:     0.6847 Validation Accuracy: 0.680400
# Epoch  4, CIFAR-10 Batch 4:  Loss:     0.6972 Validation Accuracy: 0.667800
# Epoch  4, CIFAR-10 Batch 5:  Loss:     0.6126 Validation Accuracy: 0.677600
# Epoch  5, CIFAR-10 Batch 1:  Loss:     0.6803 Validation Accuracy: 0.678000
# Epoch  5, CIFAR-10 Batch 2:  Loss:     0.6356 Validation Accuracy: 0.693000
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.5819 Validation Accuracy: 0.693400
# Epoch  5, CIFAR-10 Batch 4:  Loss:     0.5869 Validation Accuracy: 0.684800
# Epoch  5, CIFAR-10 Batch 5:  Loss:     0.5204 Validation Accuracy: 0.697800
# Epoch  6, CIFAR-10 Batch 1:  Loss:     0.5784 Validation Accuracy: 0.695400
# Epoch  6, CIFAR-10 Batch 2:  Loss:     0.5541 Validation Accuracy: 0.704200
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.5039 Validation Accuracy: 0.702400
# Epoch  6, CIFAR-10 Batch 4:  Loss:     0.4790 Validation Accuracy: 0.694600
# Epoch  6, CIFAR-10 Batch 5:  Loss:     0.4398 Validation Accuracy: 0.714600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     0.4684 Validation Accuracy: 0.702400
# Epoch  7, CIFAR-10 Batch 2:  Loss:     0.4645 Validation Accuracy: 0.716400
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.4260 Validation Accuracy: 0.718800
# Epoch  7, CIFAR-10 Batch 4:  Loss:     0.4132 Validation Accuracy: 0.703600
# Epoch  7, CIFAR-10 Batch 5:  Loss:     0.3510 Validation Accuracy: 0.724600
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.3910 Validation Accuracy: 0.715800
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.3874 Validation Accuracy: 0.725800
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.3627 Validation Accuracy: 0.723800
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.3233 Validation Accuracy: 0.715400
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.3082 Validation Accuracy: 0.726000
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.3119 Validation Accuracy: 0.724400
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.3236 Validation Accuracy: 0.731800
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.3096 Validation Accuracy: 0.733200
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.2713 Validation Accuracy: 0.715600
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.2508 Validation Accuracy: 0.732000
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.2614 Validation Accuracy: 0.723400
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.2707 Validation Accuracy: 0.731400
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.2621 Validation Accuracy: 0.729800
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.2259 Validation Accuracy: 0.723200
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.2034 Validation Accuracy: 0.730800
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.2280 Validation Accuracy: 0.737000
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.2207 Validation Accuracy: 0.736600
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.2120 Validation Accuracy: 0.736000
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.1803 Validation Accuracy: 0.728600
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.1730 Validation Accuracy: 0.748600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.1720 Validation Accuracy: 0.740000
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.1780 Validation Accuracy: 0.740200
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.1712 Validation Accuracy: 0.744400
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.1421 Validation Accuracy: 0.728800
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.1403 Validation Accuracy: 0.743800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.1525 Validation Accuracy: 0.732400
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.1426 Validation Accuracy: 0.740400
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.1294 Validation Accuracy: 0.744000
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.1141 Validation Accuracy: 0.728200
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.1202 Validation Accuracy: 0.741400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.1404 Validation Accuracy: 0.741200
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.1205 Validation Accuracy: 0.737400
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.1148 Validation Accuracy: 0.744200
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.0941 Validation Accuracy: 0.738400
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.1022 Validation Accuracy: 0.744000
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.1118 Validation Accuracy: 0.731600
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.1040 Validation Accuracy: 0.736800
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.0990 Validation Accuracy: 0.743800
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.0778 Validation Accuracy: 0.739800
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.0841 Validation Accuracy: 0.743600
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.1079 Validation Accuracy: 0.745000
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.0892 Validation Accuracy: 0.741200
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.0940 Validation Accuracy: 0.743800
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.0681 Validation Accuracy: 0.741000
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.0698 Validation Accuracy: 0.743000
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.0786 Validation Accuracy: 0.741200
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.0764 Validation Accuracy: 0.745400
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.0719 Validation Accuracy: 0.740600
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.0542 Validation Accuracy: 0.744400
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.0576 Validation Accuracy: 0.738400
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.0600 Validation Accuracy: 0.747800
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.0633 Validation Accuracy: 0.739600
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.0612 Validation Accuracy: 0.740800
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.0403 Validation Accuracy: 0.744400
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.0473 Validation Accuracy: 0.745800
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.0556 Validation Accuracy: 0.746200
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.0536 Validation Accuracy: 0.734800
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.0503 Validation Accuracy: 0.733200
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.0416 Validation Accuracy: 0.747200
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.0397 Validation Accuracy: 0.746200
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.0500 Validation Accuracy: 0.739400
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.0454 Validation Accuracy: 0.739800
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.0509 Validation Accuracy: 0.740800
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.0347 Validation Accuracy: 0.744000
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.0391 Validation Accuracy: 0.738800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.0490 Validation Accuracy: 0.738600
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.0415 Validation Accuracy: 0.742800
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.0345 Validation Accuracy: 0.738200
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.0266 Validation Accuracy: 0.751200
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.0311 Validation Accuracy: 0.745200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.0378 Validation Accuracy: 0.745000
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.0442 Validation Accuracy: 0.742600
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.0351 Validation Accuracy: 0.748800
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.0342 Validation Accuracy: 0.746400
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.0258 Validation Accuracy: 0.746200
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.0310 Validation Accuracy: 0.744400
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.0308 Validation Accuracy: 0.746200
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.0319 Validation Accuracy: 0.738800
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.0276 Validation Accuracy: 0.748200
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.0297 Validation Accuracy: 0.753600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0283 Validation Accuracy: 0.742000
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.0250 Validation Accuracy: 0.746000
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.0258 Validation Accuracy: 0.743600
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.0250 Validation Accuracy: 0.747400
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.0230 Validation Accuracy: 0.752800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0200 Validation Accuracy: 0.748800
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.0243 Validation Accuracy: 0.748200
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.0210 Validation Accuracy: 0.746200
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.0188 Validation Accuracy: 0.743600
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.0187 Validation Accuracy: 0.752600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.0127 Validation Accuracy: 0.751000
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.0178 Validation Accuracy: 0.756000
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.0207 Validation Accuracy: 0.748600
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.0141 Validation Accuracy: 0.752000
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.0173 Validation Accuracy: 0.758000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0093 Validation Accuracy: 0.753800
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.0160 Validation Accuracy: 0.759200
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.0133 Validation Accuracy: 0.755400
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.0088 Validation Accuracy: 0.748800
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.0174 Validation Accuracy: 0.744200
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0086 Validation Accuracy: 0.750400
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.0156 Validation Accuracy: 0.752400
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.0116 Validation Accuracy: 0.755000
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.0097 Validation Accuracy: 0.752200
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.0162 Validation Accuracy: 0.759800
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0079 Validation Accuracy: 0.759000
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.0118 Validation Accuracy: 0.750800
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.0131 Validation Accuracy: 0.757400
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.0084 Validation Accuracy: 0.759200
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.0142 Validation Accuracy: 0.757200
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0069 Validation Accuracy: 0.755600
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.0086 Validation Accuracy: 0.753400
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.0082 Validation Accuracy: 0.754800
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.0061 Validation Accuracy: 0.752400
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.0117 Validation Accuracy: 0.759800
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0079 Validation Accuracy: 0.762000
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.0109 Validation Accuracy: 0.754200
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.0081 Validation Accuracy: 0.753600
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.0096 Validation Accuracy: 0.752800
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.0088 Validation Accuracy: 0.758400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0090 Validation Accuracy: 0.756400
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.0102 Validation Accuracy: 0.758000
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.0064 Validation Accuracy: 0.748800
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.0068 Validation Accuracy: 0.757200
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.0059 Validation Accuracy: 0.757400
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0073 Validation Accuracy: 0.763400
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.0058 Validation Accuracy: 0.753400
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.0065 Validation Accuracy: 0.751000
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.0083 Validation Accuracy: 0.755400
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.0057 Validation Accuracy: 0.756200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0066 Validation Accuracy: 0.757200
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.0059 Validation Accuracy: 0.761600
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.0056 Validation Accuracy: 0.754400
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.0053 Validation Accuracy: 0.753800
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.0056 Validation Accuracy: 0.752200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0053 Validation Accuracy: 0.752600
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.0053 Validation Accuracy: 0.758000
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.0051 Validation Accuracy: 0.757800
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.0055 Validation Accuracy: 0.759600
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.0051 Validation Accuracy: 0.754800
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0030 Validation Accuracy: 0.760400
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.0054 Validation Accuracy: 0.757600
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.0054 Validation Accuracy: 0.754600
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.0055 Validation Accuracy: 0.755800
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.0047 Validation Accuracy: 0.757000
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0031 Validation Accuracy: 0.754400
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.0047 Validation Accuracy: 0.751600
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.0056 Validation Accuracy: 0.756600
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.0048 Validation Accuracy: 0.755400
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.0059 Validation Accuracy: 0.759400
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0031 Validation Accuracy: 0.760000
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.0026 Validation Accuracy: 0.755400
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.0069 Validation Accuracy: 0.755200
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.0036 Validation Accuracy: 0.755400
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.0052 Validation Accuracy: 0.759200
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0059 Validation Accuracy: 0.755400
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.0055 Validation Accuracy: 0.760400
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.0095 Validation Accuracy: 0.755200
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.0034 Validation Accuracy: 0.757200
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.0064 Validation Accuracy: 0.761000
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0075 Validation Accuracy: 0.756400
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.0026 Validation Accuracy: 0.761200
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.0034 Validation Accuracy: 0.758600
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.0029 Validation Accuracy: 0.754200
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.0035 Validation Accuracy: 0.757400
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0018 Validation Accuracy: 0.761600
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.0045 Validation Accuracy: 0.760600
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.0021 Validation Accuracy: 0.753400
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.0045 Validation Accuracy: 0.757000
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.0025 Validation Accuracy: 0.761200
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0026 Validation Accuracy: 0.755600
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.0033 Validation Accuracy: 0.761600
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.0022 Validation Accuracy: 0.760600
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.0045 Validation Accuracy: 0.756000
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.0027 Validation Accuracy: 0.757600
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0019 Validation Accuracy: 0.751200
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.0038 Validation Accuracy: 0.758200
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.0020 Validation Accuracy: 0.756200
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.0044 Validation Accuracy: 0.749000
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.0038 Validation Accuracy: 0.760800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0043 Validation Accuracy: 0.759000
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.0050 Validation Accuracy: 0.761000
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.0028 Validation Accuracy: 0.759400
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.0017 Validation Accuracy: 0.758000
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.0039 Validation Accuracy: 0.762400
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0017 Validation Accuracy: 0.759200
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.0032 Validation Accuracy: 0.758600
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.0030 Validation Accuracy: 0.756800
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.0032 Validation Accuracy: 0.753800
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.0019 Validation Accuracy: 0.759200
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0021 Validation Accuracy: 0.757400
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.0026 Validation Accuracy: 0.761000
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.0033 Validation Accuracy: 0.765000
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.0018 Validation Accuracy: 0.756200
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.0023 Validation Accuracy: 0.760800
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0013 Validation Accuracy: 0.758800
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.0026 Validation Accuracy: 0.755200
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.0016 Validation Accuracy: 0.760000
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.0023 Validation Accuracy: 0.758600
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.0024 Validation Accuracy: 0.764400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0015 Validation Accuracy: 0.764800
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.0027 Validation Accuracy: 0.761400
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0037 Validation Accuracy: 0.755200
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.0017 Validation Accuracy: 0.755600
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.0024 Validation Accuracy: 0.764800
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.769400
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.0029 Validation Accuracy: 0.767400
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.0036 Validation Accuracy: 0.765200
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.0022 Validation Accuracy: 0.758600
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.0014 Validation Accuracy: 0.759400
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0016 Validation Accuracy: 0.767800
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.0023 Validation Accuracy: 0.757400
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0020 Validation Accuracy: 0.765200
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.0014 Validation Accuracy: 0.759600
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.0028 Validation Accuracy: 0.761200
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy: 0.761000
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.0034 Validation Accuracy: 0.759200
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.0032 Validation Accuracy: 0.762600
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.0056 Validation Accuracy: 0.756800
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.0011 Validation Accuracy: 0.768800
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy: 0.766600
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.0014 Validation Accuracy: 0.758200
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.0024 Validation Accuracy: 0.766800
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.0021 Validation Accuracy: 0.763400
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.0016 Validation Accuracy: 0.757000
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0014 Validation Accuracy: 0.763800
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.0035 Validation Accuracy: 0.758400
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.0012 Validation Accuracy: 0.766200
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.0022 Validation Accuracy: 0.759000
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.0014 Validation Accuracy: 0.765200
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.766000
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.0011 Validation Accuracy: 0.762600
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.0016 Validation Accuracy: 0.758600
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.0010 Validation Accuracy: 0.764400
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.0016 Validation Accuracy: 0.765400
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.769000
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.0008 Validation Accuracy: 0.765600
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.0027 Validation Accuracy: 0.765600
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.0011 Validation Accuracy: 0.764000
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.0024 Validation Accuracy: 0.766400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.766600
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.0023 Validation Accuracy: 0.757000
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.0032 Validation Accuracy: 0.765400
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.0009 Validation Accuracy: 0.760600
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.0014 Validation Accuracy: 0.760400
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.762200
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.0016 Validation Accuracy: 0.762800
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.0019 Validation Accuracy: 0.762000
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.0011 Validation Accuracy: 0.763800
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.0013 Validation Accuracy: 0.760200
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy: 0.761600
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.0010 Validation Accuracy: 0.762200
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0021 Validation Accuracy: 0.760000
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.0013 Validation Accuracy: 0.764800
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.0010 Validation Accuracy: 0.764600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy: 0.768200
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.0008 Validation Accuracy: 0.763800
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.0006 Validation Accuracy: 0.766600
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.0022 Validation Accuracy: 0.765800
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.0012 Validation Accuracy: 0.768000
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.762600
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.0007 Validation Accuracy: 0.762200
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0022 Validation Accuracy: 0.760600
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.0014 Validation Accuracy: 0.760600
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0028 Validation Accuracy: 0.762600
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0015 Validation Accuracy: 0.766600
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.0018 Validation Accuracy: 0.764400
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.0013 Validation Accuracy: 0.763000
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.0015 Validation Accuracy: 0.757800
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.0009 Validation Accuracy: 0.755200
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.760800
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.0014 Validation Accuracy: 0.762400
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.0018 Validation Accuracy: 0.759200
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.0006 Validation Accuracy: 0.757200
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0015 Validation Accuracy: 0.760200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.761600
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.0013 Validation Accuracy: 0.764000
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.0024 Validation Accuracy: 0.761000
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0018 Validation Accuracy: 0.761600
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.0007 Validation Accuracy: 0.763400
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.764800
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.0008 Validation Accuracy: 0.758200
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.0018 Validation Accuracy: 0.765800
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.0009 Validation Accuracy: 0.762200
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.0012 Validation Accuracy: 0.756600
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.762600
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.0005 Validation Accuracy: 0.763400
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0014 Validation Accuracy: 0.758400
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.0010 Validation Accuracy: 0.756000
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0008 Validation Accuracy: 0.753400

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.7632872343063355

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
